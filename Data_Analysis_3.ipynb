# %% [markdown]
# <a href="https://colab.research.google.com/github/Sikandarh11/Data-Analysis/blob/main/Data_Analysis_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from wordcloud import WordCloud

# %%
df = pd.read_csv("/content/Instagram data.csv", encoding='latin1')

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
px.histogram(df['Impressions'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
sns.kdeplot(df['Impressions'])
# Out:
# <Axes: xlabel='Impressions', ylabel='Density'>

# %%
col = ['From Home',	'From Hashtags',	'From Explore',	'From Other']
piedf = df[col]
val = []
for i in col:
  val.append(sum((df[i])))

# %%
import matplotlib.pyplot as plt

plt.pie(val, labels = col, autopct = "%1.2f%%", startangle=90, shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a2c308835b0>,
# ...
#  [Text(-1.0812351963641982, 0.20231275328874898, 'From Home'),
#   Text(0.6972914288260523, -0.8507553486671257, 'From Hashtags'),
#   Text(0.7852533978800613, 0.7703097436212386, 'From Explore'),
#   Text(0.10518487162763868, 1.0949594251755073, 'From Other')],
#  [Text(-0.5897646525622898, 0.11035241088477216, '44.11%'),
#   Text(0.38034077935966487, -0.4640483720002503, '33.63%'),
#   Text(0.4283200352073061, 0.4201689510661301, '19.21%'),
#   Text(0.05737356634234836, 0.5972505955502766, '3.05%')])

# %%
column = ['Likes',	'Saves',	'Shares',	'Comments']
piedf = df[column]
value = []
for i in column:
  value.append(sum((df[i])))

# %%
plt.pie(value, labels =column, startangle = 90, autopct = "%1.2f%%", shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a2c30b303a0>,
# ...
#  [Text(-1.0997722203581946, -0.022384443893175072, 'Likes'),
#   Text(1.091227642248683, -0.1386442670736165, 'Saves'),
#   Text(0.22687592065271606, 1.076349068206027, 'Shares'),
#   Text(0.06707451806084944, 1.0979530996481157, 'Comments')],
#  [Text(-0.5998757565590151, -0.012209696669004585, '50.65%'),
#   Text(0.5952150775901907, -0.07562414567651807, '44.68%'),
#   Text(0.12375050217420874, 0.587099491748742, '2.73%'),
#   Text(0.03658610076046333, 0.5988835088989721, '1.94%')])

# %%
plt.plot(df['Profile Visits'], df['Follows'])
